# %% [markdown]
# 今天有一道题目儿子做的很棒，题目如下：

# %%
from IPython.core.display import Image, display
display(Image('./倒水流程图题目.png', width=700, unconfined=True))

# %%
from IPython.core.display import Image, display
display(Image('./倒水流程图.png', width=400, unconfined=True))

# %%
def daoshui():
    a=2 #假设第1个杯子中的水是2
    b=0
    n=1 #倒水的次数
    while n<=2017:
        if n%2!=0:
            b=round(b+a*1/(n+1),2)
            a-=round(a*1/(n+1),2)
        else:
            a=round(a+b*1/(n+1),2)
            b-=round(b*1/(n+1),2)
        n+=1
    print("两水杯中在倒了 %s 次之后，其比为：%d:%d" % (n-1, a,b))

daoshui()
# Out:
# 两水杯中在倒了 2017 次之后，其比为：1:1
